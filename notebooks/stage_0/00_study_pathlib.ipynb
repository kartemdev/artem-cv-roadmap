# %%
from pathlib import Path

# %%
Path('../../main.py').exists()
# Out:
# True

# %%
Path('../../tests').mkdir(exist_ok = True)
Path('../../tests').exists()
# Out:
# True

# %%
sorted(Path('../../').glob(('*.py')))
# Out:
# [PosixPath('../../main.py')]

# %%
sorted(Path('../../').glob(('**/*.gitkeep')))
# Out:
# [PosixPath('../../data/interim/.gitkeep'),
#  PosixPath('../../data/processed/.gitkeep'),
#  PosixPath('../../data/raw/.gitkeep'),
#  PosixPath('../../notebooks/.gitkeep'),
#  PosixPath('../../reports/.gitkeep'),
#  PosixPath('../../scripts/.gitkeep'),
#  PosixPath('../../src/cv_lab/.gitkeep'),
#  PosixPath('../../tests/.gitkeep')]

# %%
sorted(Path('../../src').glob(('*/config.py')))
# Out:
# [PosixPath('../../src/cv_lab/config.py')]

# %%
sorted(Path('../../').rglob(('config.py')))
# Out:
# [PosixPath('../../.venv/lib/python3.13/site-packages/IPython/core/magics/config.py'),
#  PosixPath('../../.venv/lib/python3.13/site-packages/cv2/config.py'),
#  PosixPath('../../.venv/lib/python3.13/site-packages/fsspec/config.py'),
#  PosixPath('../../.venv/lib/python3.13/site-packages/ipykernel/pylab/config.py'),
#  PosixPath('../../.venv/lib/python3.13/site-packages/matplotlib_inline/config.py'),
#  PosixPath('../../.venv/lib/python3.13/site-packages/pandas/_config/config.py'),
#  PosixPath('../../.venv/lib/python3.13/site-packages/pydantic/config.py'),
#  PosixPath('../../.venv/lib/python3.13/site-packages/pydantic/deprecated/config.py'),
#  PosixPath('../../.venv/lib/python3.13/site-packages/pydantic/v1/config.py'),
#  PosixPath('../../.venv/lib/python3.13/site-packages/setuptools/_distutils/command/config.py'),
#  PosixPath('../../.venv/lib/python3.13/site-packages/starlette/config.py'),
#  PosixPath('../../.venv/lib/python3.13/site-packages/torch/_dynamo/config.py'),
# ...

# %%
Path('../../src/cv_lab/config.py').suffix
# Out:
# '.py'

# %%
Path('../../src/cv_lab/config.py').name
# Out:
# 'config.py'

# %%
Path('../../src/cv_lab/config.py').stem
# Out:
# 'config'

# %%
Path('../../src/cv_lab/config.py').parent
# Out:
# PosixPath('../../src/cv_lab')

# %%
Path('../../src/cv_lab/config.py').resolve()
# Out:
# PosixPath('/Users/artemkulikov/artem-cv-roadmap/src/cv_lab/config.py')

# %%
target = Path('../../src/cv_lab/config.py').resolve()
base = Path.cwd()

result = target.relative_to(base, walk_up=True)
print(result)
# Out:
# ../../src/cv_lab/config.py

# %%
Path('../../src/cv_lab/config.py').absolute()
# Out:
# PosixPath('/Users/artemkulikov/artem-cv-roadmap/notebooks/stage_0/../../src/cv_lab/config.py')
