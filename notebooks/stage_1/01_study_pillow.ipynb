# %%
from PIL import Image, UnidentifiedImageError
from pathlib import Path
from cv_lab.config import DATA_DIR

raw_data_dir = Path('../../') / DATA_DIR / 'raw'

yamaha_path = raw_data_dir / 'yamaha_mt_09.jpg'
yamaha_image = Image.open(yamaha_path)

broken_path = raw_data_dir / 'broken_image.jpg'

# %%
yamaha_image.size
# Out:
# (736, 490)

# %%
yamaha_image.width
# Out:
# 736

# %%
yamaha_image.height
# Out:
# 490

# %%
yamaha_image.mode
# Out:
# 'RGB'

# %%
yamaha_image.format
# Out:
# 'JPEG'

# %%
try:
    Image.open(broken_path)
    print("Файл цел и невредим!")
except UnidentifiedImageError as e:
    print("Файл поврежден:", e)
# Out:
# Файл поврежден: cannot identify image file '/Users/artemkulikov/artem-cv-roadmap/data/raw/broken_image.jpg'

# %%
try:
    yamaha_image.verify()
    print("Файл цел и невредим!")
except Exception as e:
    print("Файл поврежден:", e)

with Image.open(yamaha_path) as yamaha_image:
    pixels = yamaha_image.load()
    pixels[0, 0]
# Out:
# Файл цел и невредим!
